# %%
## INstall dependencies

# %pip install anthropic python-dotenv

# %%
## Load env varaibles

from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
## create an API client

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
## make a request

message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role":"user",
            "content": "what is quantum computing? Answer in one sentence"
        }
    ])

# %%
## helper functions

def add_user_message(messages, text):
    user_mesg = {
        "role": "user",
        "content": text
    }
    messages.append(user_mesg)

def add_assistant_message(messages, text):
    assistant_mesg = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_mesg)

def chat(messages):
    response = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return response.content[0].text

# %%
messages = []
add_user_message(messages, "Define quantum computing in one sentence")
answer = chat(messages)
add_assistant_message(messages, answer)
add_user_message(messages, "Write another sentence")
answer = chat(messages)
add_assistant_message(messages, answer)
messages
# Out:
# [{'role': 'user', 'content': 'Define quantum computing in one sentence'},
#  {'role': 'assistant',
#   'content': '**Quantum computing** is a form of computation that harnesses quantum mechanical phenomena such as superposition and entanglement to process information in ways that can solve certain problems exponentially faster than classical computers.'},
#  {'role': 'user', 'content': 'Write another sentence'},
#  {'role': 'assistant',
#   'content': 'Unlike classical computers, which store information as binary bits (0s and 1s), quantum computers use **qubits** that can exist in multiple states simultaneously, enabling them to explore many possible solutions to a problem at the same time.'}]

# %%
messages = []
while True:
    input_text = input("input > ")
    if not input_text:
        break
    print("> " + input_text)
    add_user_message(messages, input_text)
    answer = chat(messages)
    add_assistant_message(messages, answer)
    print(answer)
# Out:
# > What is the capital of France ?
# The capital of France is **Paris**. It is the country's largest city and serves as its political, cultural, and economic center.
# > What are the best places to visit there ?
# Here are some of the best places to visit in Paris:
#
# ## Iconic Landmarks
# - **Eiffel Tower** - The most famous symbol of Paris, offering stunning views of the city
# - **Arc de Triomphe** - A magnificent monument at the end of the Champs-Élysées
# - **Notre-Dame Cathedral** - A masterpiece of Gothic architecture
#
# ## Museums & Art
# - **The Louvre** - One of the world's largest and most visited art museums, home to the Mona Lisa
# - **Musée d'Orsay** - Famous for its impressive collection of Impressionist art
# - **Centre Pompidou** - A modern and contemporary art museum
#
# ## Beautiful Areas
# - **Montmartre** - A charming hilltop neighborhood with artistic history
# - **Champs-Élysées** - A famous avenue lined with shops and cafes
# - **Le Marais** - A historic and trendy neighborhood
#
# ## Parks & Gardens
# - **Luxembourg Gardens** - Beautiful and relaxing green spaces
# - **Tuileries Garden** - Located near the Louvre
#
# ## Other Attractions
# - **Sainte-Chapelle** - Known for its stunning stained glass windows
# - **Versailles Palace** - A magnificent royal château just outside Paris
# - **Seine River Cruise** - A great way to see the city from the water
#
# Paris has something for everyone, whether you love art, history, food, or architecture! 🗼
# > What are best vegetarian food options available?
# Here are some of the best vegetarian food options available in Paris:
#
# ## Traditional French Vegetarian Dishes
# - **Ratatouille** - A classic French vegetable stew made with zucchini, eggplant, and tomatoes
# - **French Onion Soup** - A rich and flavorful soup topped with melted cheese
# - **Quiche Lorraine** - A savory pastry filled with eggs, cheese, and vegetables
# - **Crepes** - Thin pancakes that can be filled with sweet or savory fillings
#
# ## Popular Vegetarian Foods
# - **Croissants** - Buttery and flaky pastries perfect for breakfast
# - **Baguettes** - Fresh bread that can be paired with cheese and vegetables
# - **Cheese Platters** - France is famous for its wide variety of cheeses
# - **Macarons** - Colorful and delicious French cookies
#
# ## Vegetarian Restaurants in Paris
# - **Gentle Gourmet** - A popular vegan and vegetarian restaurant
# - **Le Potager de Charlotte** - Known for its organic vegetarian meals
# - **Hank Burger** - Offers delicious vegetarian and vegan burgers
# - **VG Patisserie** - A vegan pastry shop with amazing desserts
#
# ## Markets & Cafes
# - **Local Markets** - Fresh fruits, vegetables, and organic produce
# - **Cafe de Flore** - A famous cafe with vegetarian options
# - **Pain Quotidien** - Offers healthy and vegetarian friendly meals
#
# ## Tips for Vegetarians in Paris
# - Always check the menu carefully as some dishes may contain meat
# - Look for restaurants with a **"V"** symbol indicating vegetarian options
# - Learn a few French phrases like **"Je suis végétarien"** meaning "I am vegetarian"
# - Visit local markets for fresh and affordable vegetarian food
#
# Paris has a growing vegetarian food scene and you will find plenty of delicious options to enjoy! 🥗🥐
