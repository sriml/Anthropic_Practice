# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

model = "claude-sonnet-4-6"
client = Anthropic()

# %%
def add_user_message(messages, text):
    user_msg = {"role": "user", "content": text}
    messages.append(user_msg)

def add_assistant_message(messages, text):
    assistant_msg = {"role": "assistant", "content": text}
    messages.append(assistant_msg)

def chat(messages, system=None, temperature=0.0):
    params = {
        "model":model,
        "max_tokens":1000,
        "messages":messages
        }
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
       
    return message.content[0].text

# %%
messages = []
add_user_message(messages, "Tell me about Victoria memorial of Kolkata")

with client.messages.stream(
    model=model,
    messages=messages,
    max_tokens=1000
) as stream:
    for text in stream.text_stream:
        print(text)
# Out:
# #
#  Victoria Memorial, Kolkata
#
# ## Overview
# The Victoria Memorial is one of India's most iconic landmarks, located in **Kolkata (
# formerly Calcutta), West Bengal**. It is a magnificent white marble building dedicated
#  to the memory of **Queen Victoria**, Empress of India, who reigned from 1837 to 1901.
#
# ---
#
#
# ## Historical Background
# - Construction began in **1906** and was completed in **1921**
# - It
#  was **inaugurated on December 28, 1921** by the **
# Prince of Wales** (later King Edward VIII)
# - The idea was proposed by **Lord Curzon**, the
#  Viceroy of India, after Queen Victoria's death in 1901
# - Funded through donations
#  from Indian princes, states, and the British government
#
# ---
#
# ## Architecture
# - Designed by **Sir
#  William Emerson**, President of the British Institute of
#  Architects
# - Built in **Indo-Saracenic Revival style**,
#  blending:
#   - British and **Mughal architecture**
#   -
#  Venetian, Egyptian, and Deccani elements
# - Made
#  of **white Makrana marble** (same marble used in the Taj Mahal) from Raj
# asthan
# - The building measures approximately **103 meters long** and **69
#  meters wide**
# - Features a **rotating bronze Angel of Victory** statue (approximately
#  4.9 meters tall) on top of the central dome
# - The dome
#  rises to about **56 meters** in height
#
# ---
#
# ## The Garden
# - Surrounded
#  by **57 acres of beautiful gardens**
# - Maintained by the **Archaeological Survey of India (ASI)**
#
# - Features:
#   - Ornamental lakes and ponds
#   - Statues of Queen
#  Victoria and various British dignitaries
#   - Fountains and well-manicured lawns
#   - Statues of Lord
#  Curzon and other historical figures
#
# ---
#
# ## Museum Inside
# The Victoria Memorial houses a **museum
# ** with 25 galleries containing:
# - Over **28
# ,000 artifacts** and artworks
# - Paintings, sculptures, maps, and manuscripts
# - Personal belong
# ings of Queen Victoria
# - Rare stamps and coins
# - Portraits of Mug
# hal emperors and British officials
# - Artworks depicting Indian history and the British Raj era
# - A **Royal
#  Gallery** with paintings of Queen Victoria and Prince Albert
#
# ---
#
# ## Key Galleries
#
# | Gallery | Highlights |
# |---------|-----------|
# | Royal Gallery | Portraits of Queen Victoria |
# | Portrait Gallery | Indian
#  and British historical figures |
# | Central Hall | Marble statue of Queen Victoria |
# | Calc
# utta Gallery | History of Kolkata city |
# | Arms & Armory | Historical
#  weapons |
# | Sculpture Gallery | Marble and bronze sculptures |
#
# ---
#
# ## Light and
#  Sound Show
# - A popular **sound and light show** is held in the evenings
# - Nar
# rates the history of Kolkata and the British Raj
# - Very popular among tourists and locals
#
# ---
#
# ## Administration
# - Managed by the **
# Ministry of Culture, Government of India**
# - Protected under the **Ancient Monuments and Archaeological Sites
#  Act**
# - The gardens are maintained by the **Archaeological Survey of India**
#
# ---
#
# ## Significance
# - One of the **most visited monuments
# ** in India
# - A symbol of **colonial-era architecture** in India
# - Represents a blend
#  of Indian and Western architectural styles
# - Important **cultural and historical heritage** site
# - One of
#  Kolkata's most recognized **tourist attractions**
#
# ---
#
# ## Visiting Information
# - **Location:** Queens
#  Way, Victoria Memorial Hall, Maidan, Kolkata - 700071
#
# - **Timings:**
#   - Museum: 10:00 AM – 5:00 PM (
# closed on Mondays and national holidays)
#   - Gardens: 5:30 AM – 6
# :15 PM
# - **Nearest Metro:** Maidan / Rab
# indra Sarani
# - **Entry Fee:** Nominal fee for Indians and foreigners (
# children may have different rates)
#
# ---
#
# ## Fun Facts
# - The **
# bronze Angel of Victory** on top rotates with the wind
# - Over **3
# million visitors** visit annually
# - The marble used is the same type as the **
# Taj Mahal**
# - It took **15 years** to complete construction
# - The Victoria Memorial is sometimes called the **
# "Taj Mahal of Kolkata"**
#
# ---
#
# The Victoria Memorial stands as a **magnificent reminder of India's
